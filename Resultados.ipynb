# %% [markdown]
# #  PROYECTO FINAL DE COMPUTACION
# ## Facultad de Ciencias, UNAM
# <font face="Times New Roman">Trabajo hecho por:
#
# <font face="Times">Jared Imanol Poot Alfonso
#
# <font face="Times New Roman">Victor Humberto Hernández Moya

# %%
import math
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
lena= 8

planetas= ["Mercurio","Venus","Tierra","Marte","Jupiter","Saturno","Urano","Neptuno"]

b = [56671637453.44933, 108206428180.61703, 149576999324.1391, 226939986097.7253, 777500030823.1646, 1419094588462.0042, 2873841483924.2285, 4503277667394.11]

a = [57909176000,108208930000,149597887000,227936637000,778412027000,1421179772000,2876679082000,4503443661000]

Tp=[0.2408423681824466, 0.6151860302945245, 1.0, 1.8807584230186998, 11.869327610025852, 29.280961739292863, 84.32356010397797, 165.1691416880822]

C= [11907903818.211454, 735820724.0003357, 2499813603.303775, 21292092354.534145, 37669428562.51986, 76957737361.66525, 127740620370.15382, 38665981825.67552] 

G = 6.67*10**-11

M= 1.989*10**30

opcion= int(input("Si quiere introducir un tiempo en segundos oprime [1], si es en horas[2], si es en dias[3], y si es en años[4] Terrestres:"))

seg=31536000

hor=8760

dia=365

if opcion == 1: 
    t=float(input("Introduce tiempo:"))
    Teta=[]
    for j in range(lena): 
        Teta.append((2*np.pi/(Tp[j]*seg))*t)
    X=[] 
    Y=[]
    for i in range(lena):
        x = a[i] * np.cos(Teta[i]) 
        y = b[i] * np.sin(Teta[i]) 
        X.append(x)
        Y.append(y)
        
elif opcion == 2:
    t=float(input("Introduce tiempo:"))
    Teta=[]
    for j in range(lena): 
        Teta.append((2*np.pi/(Tp[j]*hor))*t)
    X=[] 
    Y=[]
    for i in range(lena):
        x = a[i] * np.cos(Teta[i]) 
        y = b[i] * np.sin(Teta[i]) 
        X.append(x)
        Y.append(y)
        
elif opcion == 3:
    t=float(input("Introduce tiempo:"))
    Teta=[]
    for j in range(lena): 
        Teta.append(((2*np.pi)/(Tp[j]*dia))*t)
    print(Teta)
    X=[] 
    Y=[]
    for i in range(lena):
        x = a[i] * np.cos(Teta[i]) 
        y = b[i] * np.sin(Teta[i]) 
        X.append(x)
        Y.append(y)
        
elif opcion == 4:
    t=float(input("Introduce tiempo:"))
    Teta=[]
    for j in range(lena): 
        Teta.append((2*np.pi/Tp[j])*t)
    X=[] 
    Y=[]
    for i in range(lena):
        x = a[i] * np.cos(Teta[i]) 
        y = b[i] * np.sin(Teta[i]) 
        X.append(x)
        Y.append(y)
        
X1=[]
Y1=[]
X2=[]
Y2=[]
for i in range(4):
    X1.append(X[i])
    Y1.append(Y[i])
for j in range(4,8):
    X2.append(X[j])
    Y2.append(Y[j])
    
R=[]
for i in range(8):
    r =np.sqrt((X[i]-C[i])**2 + (Y[i]-0)**2)
    R.append(r)
    
    
V= []
for i in range(8):
    v= np.sqrt(G*M/R[i])
    V.append(v/1000)
    
    
aUA=[] 
for i in a:
    ua=i/a[2]
    aUA.append(ua)
    
    
a3=[]
for l in aUA:
    A=l**3
    a3.append(A)
    
    
Tp2=[]
for k in Tp:
    TP=k**2
    Tp2.append(TP)
    
    
K=[] 
for f in range(lena):
    k= Tp2[f]/a3[f]
    K.append(k)
    
plt.plot(a3,Tp2)
plt.plot(a3,Tp2,'o')
plt.title("Periodo al cuadrado vs semieje mayor al cubo")
plt.xlabel("$a^3$")
plt.ylabel("$T^2$")
plt.show()

plt.plot(planetas, K, 'o')
plt.plot(planetas, K)
plt.title("$Constante$ vs $Planeta$")
plt.xlabel("Planeta")
plt.ylabel("$K$")
plt.show()  
    
for i in range(8):
    angulo = np.linspace(0, 2*np.pi, 99+1)
    x = a[i] * np.cos(angulo) 
    y = b[i] * np.sin(angulo) 
    plt.plot(x, y)
    
plt.title("$Orbitas y posiciones Sis.Sol.$")
plt.xlabel("X")
plt.ylabel("Y")
plt.gca().set_aspect('equal')
plt.grid()
plt.plot(X, Y, "or") 
plt.show()

for i in range(4):
    angulo = np.linspace(0, 2*np.pi, 99+1)
    x = a[i] * np.cos(angulo) 
    y = b[i] * np.sin(angulo) 
    plt.plot(x, y)
    
plt.title("Or.-pos. planetas interiores ")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(X1, Y1, "or") 
plt.gca().set_aspect('equal')
plt.grid()
plt.show()

for i in range(4, 8, 1):
    angulo = np.linspace(0, 2*np.pi, 99+1)
    x = a[i] * np.cos(angulo) 
    y = b[i] * np.sin(angulo) 
    plt.plot(x, y)
    
plt.title("Or.-pos. planetas externos")
plt.xlabel("X")
plt.ylabel("Y")
plt.gca().set_aspect('equal')
plt.grid()
plt.plot(X2, Y2, "or") 
plt.show()
# Out:
# Si quiere introducir un tiempo en segundos oprime [1], si es en horas[2], si es en dias[3], y si es en años[4] Terrestres: 3
# Introduce tiempo: 100
# [7.147499192500713, 2.798211512182509, 1.7214206321039962, 0.9152800333288102, 0.14503101512253624, 0.05878975722966019, 0.020414468150791325, 0.010422168538932389]

# %%
SisSol = {"Planetas": ["Mercurio","Venus","Tierra","Marte","Jupiter","Saturno","Urano","Neptuno"],
        'Semieje Mayor (m)': ["57 909 176 000","108 208 930 000","149 597 887 000","227 936 637 000","778 412 027 000","1 421 179 772 000","2 876 679 082 000","4 503 443 661 000"],
        "Semieje Menor (m)": b,
        "Periodo en años (Tierra)": Tp,
        "Tiempo":[t,t,t,t,t,t,t,t],
        "PosicionX": X,
        "PosicionY": Y,
        "Velocidad orbital en km/s": V,
        "Const. de propor.": K,
        'Excentricidades': [0.205630690,0.0068,0.01671022,0.09341233,0.04839266,0.0541506,0.044405586,0.00858587]
        }
df = pd.DataFrame(SisSol)
df
# Out:
#    Planetas  Semieje Mayor (m)  Semieje Menor (m)  Periodo en años (Tierra)  \
# 0  Mercurio     57 909 176 000       5.667164e+10                  0.240842
# 1     Venus    108 208 930 000       1.082064e+11                  0.615186
# 2    Tierra    149 597 887 000       1.495770e+11                  1.000000
# 3     Marte    227 936 637 000       2.269400e+11                  1.880758
# 4   Jupiter    778 412 027 000       7.775000e+11                 11.869328
# 5   Saturno  1 421 179 772 000       1.419095e+12                 29.280962
# 6     Urano  2 876 679 082 000       2.873841e+12                 84.323560
# 7   Neptuno  4 503 443 661 000       4.503278e+12                165.169142
#
#    Tiempo     PosicionX     PosicionY  Velocidad orbital en km/s  \
# 0    10.0  5.788350e+10  1.687503e+09                  53.699527
# 1    10.0  1.082016e+11  1.261573e+09                  35.134219
# 2    10.0  1.495940e+11  1.072845e+09                  30.031479
# 3    10.0  2.279350e+11  8.654714e+08                  25.337757
# 4    10.0  7.784119e+11  4.698400e+08                  13.382789
# 5    10.0  1.421180e+12  3.476176e+08                   9.934472
# 6    10.0  2.876679e+12  2.444498e+08                   6.947008
# 7    10.0  4.503444e+12  1.955580e+08                   5.451053
#
#    Const. de propor.  Excentricidades
# 0                1.0         0.205631
# 1                1.0         0.006800
# 2                1.0         0.016710
# 3                1.0         0.093412
# 4                1.0         0.048393
# 5                1.0         0.054151
# 6                1.0         0.044406
# 7                1.0         0.008586

# %%
df
# Out:
#    Planetas  Semieje Mayor (m)  Semieje Menor (m)  Periodo en años (Tierra)  \
# 0  Mercurio     57 909 176 000       5.667164e+10                  0.240842
# 1     Venus    108 208 930 000       1.082064e+11                  0.615186
# 2    Tierra    149 597 887 000       1.495770e+11                  1.000000
# 3     Marte    227 936 637 000       2.269400e+11                  1.880758
# 4   Jupiter    778 412 027 000       7.775000e+11                 11.869328
# 5   Saturno  1 421 179 772 000       1.419095e+12                 29.280962
# 6     Urano  2 876 679 082 000       2.873841e+12                 84.323560
# 7   Neptuno  4 503 443 661 000       4.503278e+12                165.169142
#
#    Tiempo     PosicionX  PosicionY  Velocidad orbital en km/s  \
# 0     0.0  5.790918e+10        0.0                  53.702609
# 1     0.0  1.082089e+11        0.0                  35.134227
# 2     0.0  1.495979e+11        0.0                  30.031486
# 3     0.0  2.279366e+11        0.0                  25.337767
# 4     0.0  7.784120e+11        0.0                  13.382790
# 5     0.0  1.421180e+12        0.0                   9.934472
# 6     0.0  2.876679e+12        0.0                   6.947008
# 7     0.0  4.503444e+12        0.0                   5.451053
#
#    Const. de propor.  Excentricidades
# 0                1.0         0.205631
# 1                1.0         0.006800
# 2                1.0         0.016710
# 3                1.0         0.093412
# 4                1.0         0.048393
# 5                1.0         0.054151
# 6                1.0         0.044406
# 7                1.0         0.008586
